# %%
    from bs4 import BeautifulSoup  # Import BeautifulSoup for parsing HTML
    import requests  # Import requests for making HTTP requests
    import pandas as pd  # Import pandas for data manipulation and structured output
    import json # Import json for parsing the JSON data embedded in the HTML

    def scrape_car_details(url):
        """
        Scrapes car details from the given car collection URL by parsing both
        HTML elements and embedded JSON data.

        Args:
            url (str): The URL of the car collection page.

        Returns:
            list: A list of dictionaries, where each dictionary contains
                details of a car variant. Returns an empty list if scraping fails.
        """
        try:
            # 1. Send an HTTP GET request to the specified URL to retrieve the webpage content.
            response = requests.get(url)

            # 2. Check if the request was successful (status code 200).
            if response.status_code == 200:
                print("Successfully accessed the website.")
            else:
                # If the request was not successful, print an error and return an empty list.
                print(f"Failed to access the website. Status code: {response.status_code}")
                return []

            # 3. Parse the HTML content of the response using BeautifulSoup.
            # 'html.parser' is a built-in Python HTML parser.
            soup = BeautifulSoup(response.content, 'html.parser')

            # Find the script tag containing the __NEXT_DATA__ JSON.
            # This JSON often holds the structured data used by modern web applications.
            next_data_script = soup.find('script', id='__NEXT_DATA__')

            if not next_data_script:
                print("Could not find __NEXT_DATA__ script tag. Data extraction may be incomplete.")
                # Fallback to HTML-only scraping if JSON is not found, or return empty if essential
                # For this task, JSON is essential for detailed colors, so returning empty.
                return []

            # Extract the JSON string and parse it into a Python dictionary.
            json_data = json.loads(next_data_script.string)

            # Navigate through the JSON structure to find the main listing data.
            # The path is typically props -> pageProps -> listingData -> result
            listing_results = json_data.get('props', {}).get('pageProps', {}).get('listingData', {}).get('result', [])

            # Extract the global selected city from the JSON for location details.
            global_city = json_data.get('props', {}).get('pageProps', {}).get('cities', {}).get('selectedCity', 'N/A')
            location_details = f"in {global_city}" if global_city != 'N/A' else 'N/A'

            car_data = [] # Initialize an empty list to store dictionaries of car details

            # Iterate through each car model found in the JSON data.
            for car_model_json in listing_results:
                car_make = car_model_json.get('brand_name', 'N/A')
                car_model_base_name = car_model_json.get('model_name', 'N/A')

                # Iterate through each variant of the current car model.
                variants = car_model_json.get('variants', [])
                for variant_json in variants:
                    variant_name = variant_json.get('variant_name', 'N/A')

                    # Combine the base model name and variant name for the full car model.
                    full_car_model = f"{car_model_base_name} {variant_name}".strip()

                    # Extract price information. The 'final_price' is usually in a base unit (e.g., paise/rupees).
                    # Convert to Lakhs (1 Lakh = 100,000) and format.
                    price_info = variant_json.get('price', {})
                    raw_price = price_info.get('final_price')
                    price = f"₹{raw_price / 100000:.2f} L" if isinstance(raw_price, (int, float)) else "N/A"

                    # Extract basic features like fuel type and transmission.
                    basic_features = variant_json.get('basic_feature', {})
                    fuel_type = basic_features.get('fuel_type', 'N/A')
                    transmission_type = basic_features.get('transmission', 'N/A')

                    # Extract detailed available colors from the 'colors' array in JSON.
                    available_colors_list = []
                    colors_json = variant_json.get('colors', [])
                    for color_item in colors_json:
                        color_details = color_item.get('color', {})
                        brand_color = color_details.get('brand_color', 'Unknown Color')
                        hex_codes = color_details.get('hex_codes', [])

                        if hex_codes:
                            # Format as "Color Name (Hex Code)"
                            available_colors_list.append(f"{brand_color} ({', '.join(hex_codes)})")
                        else:
                            available_colors_list.append(brand_color) # Fallback if no hex code

                    # Create a text summary for the number of available colors.
                    num_colors_text = f"Available in {len(colors_json)} colors" if colors_json else "N/A"
                    # Join all detailed colors into a single string for the output column.
                    all_colors_detailed = "; ".join(available_colors_list) if available_colors_list else "N/A"

                    # Append the extracted details as a dictionary to the car_data list.
                    car_data.append({
                        "Car Make": car_make,
                        "Car Model": full_car_model,
                        "Price": price,
                        "Fuel Type": fuel_type,
                        "Transmission Type": transmission_type,
                        "Available Color Variants Count": num_colors_text,
                        "Available Colors (Detailed)": all_colors_detailed, # New column for detailed colors
                        "Location Details": location_details
                    })
            return car_data # Return the list of all scraped car data

        # Handle potential network or request-related errors.
        except requests.exceptions.RequestException as e:
            print(f"An error occurred during the request: {e}")
            return []
        # Handle errors specific to JSON parsing.
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON from __NEXT_DATA__ script tag: {e}")
            return []
        # Handle any other unexpected errors during scraping.
        except Exception as e:
            print(f"An unexpected error occurred: {e}")
            return []

    # Main execution block: This code runs when the script is executed directly.
    if __name__ == "__main__":
        # Define the target website URL for Tata cars.
        website_url = 'https://ackodrive.com/collection/tata-cars/'

        # Call the scraping function with the URL.
        scraped_cars = scrape_car_details(website_url)

        # If data was successfully scraped, process and display it.
        if scraped_cars:
            # Convert the list of dictionaries into a pandas DataFrame for better readability and structure.
            df = pd.DataFrame(scraped_cars)

            # Set pandas display options to show all columns and more rows if needed
            pd.set_option('display.max_columns', None)
            pd.set_option('display.width', 1000)
            pd.set_option('display.max_rows', None)

            print("\n--- Scraped Car Data ---")
            print(df) # Print the DataFrame to the console

            # Save the DataFrame to a CSV file.
            # index=False prevents pandas from writing the DataFrame index as a column in the CSV.
            df.to_csv("scraped_tata_cars_with_colors.csv", index=False)
            print("\nData saved to scraped_tata_cars_with_colors.csv")
        else:
            print("No car data was scraped.")
# Out:
# Successfully accessed the website.
#
# --- Scraped Car Data ---
#     Car Make                                          Car Model     Price Fuel Type Transmission Type Available Color Variants Count                        Available Colors (Detailed) Location Details
# 0       Tata                                         Punch Pure   ₹6.41 L    Petrol            Manual          Available in 2 colors      Orcus White (#f1f6f9); Daytona Grey (#7c858c)              N/A
# 1       Tata                                      Punch Pure(O)   ₹7.49 L    Petrol            Manual          Available in 2 colors      Daytona Grey (#7c858c); Orcus White (#f1f6f9)              N/A
# 2       Tata                                    Punch Adventure   ₹7.87 L    Petrol            Manual          Available in 4 colors  Orcus White (#f1f6f9); Daytona Grey (#7c858c);...              N/A
# 3       Tata                                     Punch Pure CNG   ₹7.92 L       CNG            Manual          Available in 2 colors      Orcus White (#f1f6f9); Daytona Grey (#7c858c)              N/A
# 4       Tata                               Punch Adventure Plus   ₹8.26 L    Petrol            Manual          Available in 4 colors  Daytona Grey (#38393b); Orcus White (#fefefe);...              N/A
# 5       Tata                                Punch Adventure CNG   ₹8.82 L       CNG            Manual          Available in 4 colors  Orcus White (#f1f6f9); Daytona Grey (#7c858c);...              N/A
# 44      Tata                          Nexon 1.2 Pure Plus S CNG  ₹12.61 L       CNG            Manual          Available in 5 colors  Daytona Grey (#71757b); Pristine White (#ebebe...              N/A
# 45      Tata                             Nexon 1.2 Creative CNG  ₹13.74 L       CNG            Manual          Available in 6 colors  Pristine White (#ebebeb); Grassland Beige (#7d...              N/A
# 46      Tata                      Nexon 1.2 Creative Plus S CNG  ₹14.08 L       CNG            Manual          Available in 6 colors  Pristine White (#ebebeb); Ocean Blue (#24c0b0)...              N/A
# 47      Tata                     Nexon 1.2 Creative Plus PS CNG  ₹15.22 L       CNG            Manual          Available in 6 colors  Pristine White with Black Roof (#ecedef, #0000...              N/A
# 48      Tata                                Nexon 1.2 Pure Plus  ₹10.74 L    Petrol            Manual          Available in 5 colors  Royal Blue (#1e4079); Pure Grey (#bcbec0); Gra...              N/A
# 49      Tata                               Nexon 1.5 Smart Plus  ₹11.25 L    Diesel            Manual          Available in 4 colors  Royal Blue (#35407a); Grassland Beige (#7d7c5f...              N/A
# 50      Tata                            Nexon 1.2 Pure Plus AMT  ₹11.93 L    Petrol         Automatic          Available in 5 colors  Royal Blue (#1e4079); Pure Grey (#bcbec0); Gra...              N/A
# 51      Tata                             Nexon 1.5 Smart Plus S  ₹12.07 L    Diesel            Manual          Available in 4 colors  Royal Blue (#35407a); Grassland Beige (#7d7c5f...              N/A
# 52      Tata                                 Nexon 1.2 Creative  ₹12.61 L    Petrol            Manual          Available in 6 colors  Royal Blue (#35407a); Pure Grey (#b0b0b0); Gra...              N/A
# 53      Tata                                Nexon 1.5 Pure Plus  ₹12.88 L    Diesel            Manual          Available in 5 colors  Royal Blue (#1e4079); Pure Grey (#bcbec0); Gra...              N/A
# 54      Tata                          Nexon 1.2 Creative Plus S  ₹12.95 L    Petrol            Manual          Available in 6 colors  Pure Grey (#b0b0b0); Royal Blue (#35407a); Pri...              N/A
# 55      Tata                              Nexon 1.5 Pure Plus S  ₹13.23 L    Diesel            Manual          Available in 5 colors  Royal Blue (#1e4079); Pure Grey (#bcbec0); Gra...              N/A
# 56      Tata                             Nexon 1.2 Creative AMT  ₹13.40 L    Petrol         Automatic          Available in 6 colors  Royal Blue (#35407a); Pure Grey (#b0b0b0); Pri...              N/A
# 57      Tata             Nexon 1.2 Creative Plus S Dark Edition  ₹13.40 L    Petrol            Manual          Available in 1 colors                             Carbon Black (#191e24)              N/A
# 58      Tata                            Nexon 1.5 Pure Plus AMT  ₹13.70 L    Diesel         Automatic          Available in 5 colors  Royal Blue (#1e4079); Pure Grey (#bcbec0); Gra...              N/A
# 59      Tata                      Nexon 1.2 Creative Plus S AMT  ₹13.74 L    Petrol         Automatic          Available in 6 colors  Royal Blue (#35407a); Pure Grey (#b0b0b0); Pri...              N/A
# 60      Tata                             Nexon 1.2 Creative DCA  ₹13.97 L    Petrol         Automatic          Available in 6 colors  Pure Grey (#b0b0b0); Royal Blue (#35407a); Pri...              N/A
# 61      Tata                         Nexon 1.2 Creative Plus PS  ₹14.08 L    Petrol            Manual          Available in 6 colors  Ocean Blue with White Roof (#3d7479, #ebebeb);...              N/A
# 62      Tata                                 Nexon 1.5 Creative  ₹14.51 L    Diesel            Manual          Available in 6 colors  Pure Grey (#b0b0b0); Royal Blue (#35407a); Pri...              N/A
# 63      Tata            Nexon 1.2 Creative Plus PS Dark Edition  ₹14.54 L    Petrol            Manual          Available in 1 colors                             Carbon Black (#231f20)              N/A
# 64      Tata         Nexon 1.2 Creative Plus S Dark Edition CNG  ₹14.54 L       CNG            Manual          Available in 1 colors                              Atlas Black (#191e24)              N/A
# 65      Tata                          Nexon 1.5 Creative Plus S  ₹14.86 L    Diesel            Manual          Available in 6 colors  Pure Grey (#b0b0b0); Royal Blue (#35407a); Oce...              N/A
# 66      Tata                             Nexon 1.5 Creative AMT  ₹15.32 L    Diesel         Automatic          Available in 6 colors  Royal Blue (#35407a); Pure Grey (#b0b0b0); Pri...              N/A
# 67      Tata             Nexon 1.5 Creative Plus S Dark Edition  ₹15.32 L    Diesel            Manual          Available in 1 colors                              Atlas Black (#191e24)              N/A
# 68      Tata                     Nexon 1.2 Creative Plus PS DCA  ₹15.45 L    Petrol         Automatic          Available in 6 colors  Pristine White with Black Roof (#ecedef, #0000...              N/A
# 69      Tata                      Nexon 1.5 Creative Plus S AMT  ₹15.67 L    Diesel         Automatic          Available in 6 colors  Royal Blue (#35407a); Pure Grey (#b0b0b0); Oce...              N/A
# 70      Tata        Nexon 1.2 Creative Plus PS Dark Edition CNG  ₹15.67 L       CNG            Manual          Available in 1 colors                             Carbon Black (#231f20)              N/A
# 71      Tata        Nexon 1.2 Creative Plus PS DCA Dark Edition  ₹15.90 L    Petrol         Automatic          Available in 1 colors                             Carbon Black (#231f20)              N/A
# 72      Tata                         Nexon 1.5 Creative Plus PS  ₹16.02 L    Diesel            Manual          Available in 6 colors  Pristine White with Black Roof (#ecedef, #0000...              N/A
# 73      Tata            Nexon 1.5 Creative Plus PS Dark Edition  ₹16.48 L    Diesel            Manual          Available in 1 colors                             Carbon Black (#231f20)              N/A
# 74      Tata        Nexon 1.2 Fearless Plus PS Dark Edition CNG  ₹16.58 L       CNG            Manual          Available in 1 colors                             Carbon Black (#231f20)              N/A
# 75      Tata                     Nexon 1.5 Creative Plus PS AMT  ₹16.83 L    Diesel         Automatic          Available in 6 colors  Pristine White with Black Roof (#ecedef, #0000...              N/A
# 76      Tata        Nexon 1.5 Creative Plus PS AMT Dark Edition  ₹17.29 L    Diesel         Automatic          Available in 1 colors                             Carbon Black (#231f20)              N/A
# 77      Tata                         Nexon 1.2 Fearless Plus PS  ₹15.22 L    Petrol            Manual          Available in 6 colors  Pure Grey With Black Roof (#b0b0b0, #231f20); ...              N/A
# 78      Tata            Nexon 1.2 Fearless Plus PS Dark Edition  ₹15.45 L    Petrol            Manual          Available in 1 colors                             Carbon Black (#000000)              N/A
# 79      Tata                     Nexon 1.2 Fearless Plus PS CNG  ₹16.36 L       CNG            Manual          Available in 6 colors  Pure Grey With Black Roof (#b0b0b0, #231f20); ...              N/A
# 99      Tata                              Nexon EV Empowered 45  ₹16.91 L  Electric         Automatic          Available in 4 colors  Empowered Oxide With Black Roof (#acadb2, #000...              N/A
# 100     Tata                         Nexon EV Empowered Plus LR  ₹17.24 L  Electric         Automatic          Available in 4 colors  Intensi Teal With Black Roof (#00486e, #191e24...              N/A
# 101     Tata        Nexon EV Empowered Plus 45 Red Dark Edition  ₹18.15 L  Electric         Automatic          Available in 1 colors                           Empowered Dark (#000000)              N/A
# 102     Tata                               Nexon EV Creative 45  ₹14.84 L  Electric         Automatic          Available in 4 colors  Creative Ocean With White Roof (#3d7479, #ebeb...              N/A
# 103     Tata                                Harrier Pure Plus S  ₹21.64 L    Diesel            Manual          Available in 2 colors          Lunar White (#f3f3f5); Ash Grey (#b7bec4)              N/A
# 104     Tata           Harrier Fearless Plus Stealth Edition AT  ₹30.70 L    Diesel         Automatic          Available in 1 colors                            Stealth Black (#15161a)              N/A
# 105     Tata                                      Harrier Smart  ₹17.45 L    Diesel            Manual          Available in 2 colors          Ash Grey (#b7bec4); Lunar White (#f3f3f5)              N/A
# 106     Tata                                  Harrier Smart (O)  ₹18.43 L    Diesel            Manual          Available in 2 colors          Ash Grey (#b7bec4); Lunar White (#f3f3f5)              N/A
# 107     Tata                                       Harrier Pure  ₹19.33 L    Diesel            Manual          Available in 2 colors          Ash Grey (#b7bec4); Lunar White (#f3f3f5)              N/A
# 108     Tata                                   Harrier Pure (O)  ₹19.91 L    Diesel            Manual          Available in 2 colors          Ash Grey (#b7bec4); Lunar White (#f3f3f5)              N/A
# 109     Tata                                  Harrier Pure Plus  ₹21.29 L    Diesel            Manual          Available in 2 colors          Ash Grey (#b7bec4); Lunar White (#f3f3f5)              N/A
# 110     Tata                   Harrier Pure Plus S Dark Edition  ₹21.98 L    Diesel            Manual          Available in 1 colors                             Oberon Black (#18191e)              N/A
# 111     Tata                               Harrier Pure Plus AT  ₹22.21 L    Diesel         Automatic          Available in 2 colors          Ash Grey (#b7bec4); Lunar White (#f3f3f5)              N/A
# 112     Tata                                  Harrier Adventure  ₹22.44 L    Diesel            Manual          Available in 4 colors  Coral Red (#aa1b17); Lunar White (#f3f3f5); Pe...              N/A
# 113     Tata                             Harrier Pure Plus S AT  ₹22.79 L    Diesel         Automatic          Available in 2 colors          Ash Grey (#b7bec4); Lunar White (#f3f3f5)              N/A
# 114     Tata                Harrier Pure Plus S Dark Edition AT  ₹22.96 L    Diesel         Automatic          Available in 1 colors                             Oberon Black (#18191e)              N/A
# 115     Tata                             Harrier Adventure Plus  ₹24.17 L    Diesel            Manual          Available in 4 colors  Coral Red (#aa1b17); Lunar White (#f3f3f5); Pe...              N/A
# 116     Tata                Harrier Adventure Plus Dark Edition  ₹24.75 L    Diesel            Manual          Available in 1 colors                             Oberon Black (#18191e)              N/A
# 117     Tata                           Harrier Adventure Plus A  ₹25.32 L    Diesel            Manual          Available in 4 colors  Coral Red (#aa1b17); Lunar White (#f3f3f5); Pe...              N/A
# 118     Tata                          Harrier Adventure Plus AT  ₹25.79 L    Diesel         Automatic          Available in 4 colors  Coral Red (#aa1b17); Lunar White (#f3f3f5); Pe...              N/A
# 119     Tata             Harrier Adventure Plus Dark Edition AT  ₹26.36 L    Diesel         Automatic          Available in 1 colors                             Oberon Black (#18191e)              N/A
# 120     Tata                                   Harrier Fearless  ₹26.50 L    Diesel            Manual          Available in 4 colors  Coral Red With Black Roof (#aa1b17, #000000); ...              N/A
# 121     Tata                        Harrier Adventure Plus A AT  ₹26.94 L    Diesel         Automatic          Available in 4 colors  Coral Red (#aa1b17); Lunar White (#f3f3f5); Pe...              N/A
# 122     Tata                      Harrier Fearless Dark Edition  ₹27.07 L    Diesel            Manual          Available in 1 colors                             Oberon Black (#18191e)              N/A
# 123     Tata                                Harrier Fearless AT  ₹28.11 L    Diesel         Automatic          Available in 4 colors  Coral Red With Black Roof (#aa1b17, #000000); ...              N/A
# 124     Tata                              Harrier Fearless Plus  ₹28.22 L    Diesel            Manual          Available in 4 colors  Coral Red With Black Roof (#aa1b17, #000000); ...              N/A
# 125     Tata                   Harrier Fearless Dark Edition AT  ₹28.69 L    Diesel         Automatic          Available in 1 colors                             Oberon Black (#18191e)              N/A
# 126     Tata                 Harrier Fearless Plus Dark Edition  ₹28.80 L    Diesel            Manual          Available in 1 colors                             Oberon Black (#18191e)              N/A
# 127     Tata              Harrier Fearless Plus Stealth Edition  ₹29.09 L    Diesel            Manual          Available in 1 colors                            Stealth Black (#15161a)              N/A
# 128     Tata                           Harrier Fearless Plus AT  ₹29.84 L    Diesel         Automatic          Available in 4 colors  Coral Red With Black Roof (#aa1b17, #000000); ...              N/A
# 129     Tata              Harrier Fearless Plus Dark Edition AT  ₹30.41 L    Diesel         Automatic          Available in 1 colors                             Oberon Black (#18191e)              N/A
# 130     Tata                          Punch EV Adventure LR 3.3  ₹13.45 L  Electric         Automatic          Available in 4 colors  Pristine White (#f2f3f6); Fearless Red (#6f1a1...              N/A
# 131     Tata                        Punch EV Adventure S LR 3.3  ₹13.76 L  Electric         Automatic          Available in 4 colors  Daytona Grey with Black Roof (#303232, #000000...              N/A
# 132     Tata                                 Punch EV Smart 3.3  ₹10.40 L  Electric         Automatic          Available in 1 colors                           Pristine White (#f2f3f6)              N/A
# 133     Tata                            Punch EV Smart Plus 3.3  ₹11.69 L  Electric         Automatic          Available in 1 colors                           Pristine White (#f2f3f6)              N/A
# 134     Tata                             Punch EV Adventure 3.3  ₹12.42 L  Electric         Automatic          Available in 4 colors  Pristine White (#f2f3f6); Fearless Red (#6f1a1...              N/A
# 135     Tata                           Punch EV Adventure S 3.3  ₹12.73 L  Electric         Automatic          Available in 4 colors  Pristine White with Black Roof (#f2f3f6, #0000...              N/A
# 136     Tata                             Punch EV Empowered 3.3  ₹13.24 L  Electric         Automatic          Available in 5 colors  Pristine White with Black Roof (#f2f3f6, #0000...              N/A
# 137     Tata                           Punch EV Empowered S 3.3  ₹13.45 L  Electric         Automatic          Available in 5 colors  Pristine White with Black Roof (#f2f3f6, #0000...              N/A
# 138     Tata                        Punch EV Empowered Plus 3.3  ₹13.45 L  Electric         Automatic          Available in 5 colors  Pristine White with Black Roof (#f2f3f6, #0000...              N/A
# 139     Tata                      Punch EV Empowered Plus S 3.3  ₹13.76 L  Electric         Automatic          Available in 5 colors  Pristine White with Black Roof (#f2f3f6, #0000...              N/A
# 140     Tata                          Punch EV Adventure LR 7.2  ₹13.99 L  Electric         Automatic          Available in 4 colors  Pristine White (#f2f3f6); Fearless Red (#6f1a1...              N/A
# 141     Tata                          Punch EV Empowered LR 3.3  ₹14.07 L  Electric         Automatic          Available in 5 colors  Pristine White with Black Roof (#f2f3f6, #0000...              N/A
# 142     Tata                        Punch EV Empowered S LR 3.3  ₹14.28 L  Electric         Automatic          Available in 5 colors  Pristine White with Black Roof (#f2f3f6, #0000...              N/A
# 143     Tata                     Punch EV Empowered Plus LR 3.3  ₹14.28 L  Electric         Automatic          Available in 5 colors  Pristine White with Black Roof (#f2f3f6, #0000...              N/A
# 144     Tata                        Punch EV Adventure S LR 7.2  ₹14.30 L  Electric         Automatic          Available in 4 colors  Pristine White with Black Roof (#f2f3f6, #0000...              N/A
# 145     Tata                   Punch EV Empowered Plus S LR 3.3  ₹14.59 L  Electric         Automatic          Available in 5 colors  Pristine White with Black Roof (#f2f3f6, #0000...              N/A
# 146     Tata                          Punch EV Empowered LR 7.2  ₹14.61 L  Electric         Automatic          Available in 5 colors  Pristine White with Black Roof (#f2f3f6, #0000...              N/A
# 147     Tata                        Punch EV Empowered S LR 7.2  ₹14.82 L  Electric         Automatic          Available in 5 colors  Pristine White with Black Roof (#f2f3f6, #0000...              N/A
# 148     Tata                     Punch EV Empowered Plus LR 7.2  ₹14.82 L  Electric         Automatic          Available in 5 colors  Pristine White with Black Roof (#f2f3f6, #0000...              N/A
# 149     Tata                   Punch EV Empowered Plus S LR 7.2  ₹15.13 L  Electric         Automatic          Available in 5 colors  Pristine White with Black Roof (#f2f3f6, #0000...              N/A
# 150     Tata                                       Safari Smart  ₹18.12 L    Diesel            Manual          Available in 2 colors     Lunar Slate (#38393b); Stellar Frost (#fefefe)              N/A
# 151     Tata                                   Safari Smart (O)  ₹19.11 L    Diesel            Manual          Available in 2 colors     Lunar Slate (#38393b); Stellar Frost (#fefefe)              N/A
# 152     Tata                                        Safari Pure  ₹20.01 L    Diesel            Manual          Available in 2 colors     Lunar Slate (#38393b); Stellar Frost (#fefefe)              N/A
# 153     Tata                                    Safari Pure (O)  ₹20.59 L    Diesel            Manual          Available in 2 colors     Lunar Slate (#38393b); Stellar Frost (#fefefe)              N/A
# 154     Tata                                   Safari Pure Plus  ₹21.98 L    Diesel            Manual          Available in 2 colors     Lunar Slate (#38393b); Stellar Frost (#fefefe)              N/A
# 155     Tata                                 Safari Pure Plus S  ₹22.33 L    Diesel            Manual          Available in 2 colors     Lunar Slate (#38393b); Stellar Frost (#fefefe)              N/A
# 156     Tata                    Safari Pure Plus S Dark Edition  ₹22.68 L    Diesel            Manual          Available in 1 colors                             Oberon Black (#000000)              N/A
# 157     Tata                                Safari Pure Plus AT  ₹22.91 L    Diesel         Automatic          Available in 2 colors     Lunar Slate (#38393b); Stellar Frost (#fefefe)              N/A
# 158     Tata                              Safari Pure Plus S AT  ₹23.08 L    Diesel         Automatic          Available in 2 colors     Lunar Slate (#38393b); Stellar Frost (#fefefe)              N/A
# 159     Tata                                   Safari Adventure  ₹23.08 L    Diesel            Manual          Available in 4 colors  Stellar Frost (#fefefe); Stardust Ash (#6c7379...              N/A
# 160     Tata                 Safari Pure Plus S Dark Edition AT  ₹23.83 L    Diesel         Automatic          Available in 1 colors                             Oberon Black (#000000)              N/A
# 161     Tata                              Safari Adventure Plus  ₹25.22 L    Diesel            Manual          Available in 4 colors  Stellar Frost (#fefefe); Stardust Ash (#6c7379...              N/A
# 162     Tata                 Safari Adventure Plus Dark Edition  ₹25.80 L    Diesel            Manual          Available in 1 colors                             Oberon Black (#000000)              N/A
# 163     Tata                            Safari Adventure Plus A  ₹26.38 L    Diesel            Manual          Available in 4 colors  Stellar Frost (#fefefe); Stardust Ash (#6c7379...              N/A
# 164     Tata                           Safari Adventure Plus AT  ₹26.84 L    Diesel         Automatic          Available in 4 colors  Stellar Frost (#fefefe); Stardust Ash (#6c7379...              N/A
# 165     Tata              Safari Adventure Plus Dark Edition AT  ₹27.42 L    Diesel         Automatic          Available in 1 colors                             Oberon Black (#000000)              N/A
# 166     Tata                                Safari Accomplished  ₹27.79 L    Diesel            Manual          Available in 4 colors  Cosmic Gold With Black Roof (#caac7c, #000000)...              N/A
# 167     Tata                         Safari Adventure Plus A AT  ₹28.00 L    Diesel         Automatic          Available in 4 colors  Stellar Frost (#fefefe); Stardust Ash (#6c7379...              N/A
# 168     Tata                   Safari Accomplished Dark Edition  ₹28.14 L    Diesel            Manual          Available in 1 colors                             Oberon Black (#000000)              N/A
# 169     Tata                           Safari Accomplished Plus  ₹29.12 L    Diesel            Manual          Available in 4 colors  Cosmic Gold With Black Roof (#caac7c, #000000)...              N/A
# 170     Tata                        Safari Accomplished Plus 6S  ₹29.24 L    Diesel            Manual          Available in 4 colors  Cosmic Gold With Black Roof (#caac7c, #000000)...              N/A
# 171     Tata                             Safari Accomplished AT  ₹29.41 L    Diesel         Automatic          Available in 4 colors  Cosmic Gold With Black Roof (#caac7c, #000000)...              N/A
# 172     Tata              Safari Accomplished Plus Dark Edition  ₹29.47 L    Diesel            Manual          Available in 1 colors                             Oberon Black (#000000)              N/A
# 173     Tata                Safari Accomplished Dark Edition AT  ₹29.76 L    Diesel         Automatic          Available in 1 colors                             Oberon Black (#000000)              N/A
# 174     Tata           Safari Accomplished Plus Dark Edition 6S  ₹29.81 L    Diesel            Manual          Available in 1 colors                             Oberon Black (#000000)              N/A
# 175     Tata           Safari Accomplished Plus Stealth Edition  ₹29.99 L    Diesel            Manual          Available in 1 colors                            Stealth Black (#15161a)              N/A
# 176     Tata                        Safari Accomplished Plus AT  ₹30.74 L    Diesel         Automatic          Available in 4 colors  Galactic Sapphire With Black Roof (#0061aa, #0...              N/A
# 177     Tata                     Safari Accomplished Plus 6S AT  ₹30.86 L    Diesel         Automatic          Available in 4 colors  Cosmic Gold With Black Roof (#caac7c, #000000)...              N/A
# 178     Tata           Safari Accomplished Plus Dark Edition AT  ₹31.32 L    Diesel         Automatic          Available in 1 colors                             Oberon Black (#000000)              N/A
# 179     Tata        Safari Accomplished Plus Dark Edition 6S AT  ₹31.44 L    Diesel         Automatic          Available in 1 colors                             Oberon Black (#000000)              N/A
# 180     Tata        Safari Accomplished Plus Stealth Edition AT  ₹31.61 L    Diesel         Automatic          Available in 1 colors                            Stealth Black (#15161a)              N/A
# 181     Tata     Safari Accomplished Plus Stealth Edition 6S AT  ₹31.72 L    Diesel         Automatic          Available in 1 colors                            Stealth Black (#15161a)              N/A
# 182     Tata                                Curvv 1.2 Pure Plus  ₹13.12 L    Petrol            Manual          Available in 4 colors  Pristine White (#fefefe); Opera Blue (#313a72)...              N/A
# 183     Tata                                    Curvv 1.5 Smart  ₹13.63 L    Diesel            Manual          Available in 2 colors   Daytona Grey (#38393b); Pristine White (#fefefe)              N/A
# 184     Tata                              Curvv 1.2 Pure Plus S  ₹13.92 L    Petrol            Manual          Available in 4 colors  Flame Red (#6e1618); Opera Blue (#313a72); Day...              N/A
# 185     Tata                          Curvv 1.2 Pure Plus S DCA  ₹15.60 L    Petrol         Automatic          Available in 4 colors  Daytona Grey (#38393b); Pristine White (#fefef...              N/A
# 186     Tata                          Curvv 1.2 Creative Plus S  ₹16.17 L    Petrol            Manual          Available in 5 colors  Pristine White with Black roof (#fefefe, #0e0e...              N/A
# 187     Tata                             Curvv 1.2 Creative DCA  ₹16.17 L    Petrol         Automatic          Available in 5 colors  Pristine White (#fefefe); Nitro Crimson (#5c12...              N/A
# 188     Tata                           Curvv 1.2 Accomplished S  ₹17.30 L    Petrol            Manual          Available in 6 colors  Pure Grey with Black roof (#aaabb0, #0e0e0e); ...              N/A
# 189     Tata                 Curvv 1.2 Accomplished Plus A Dark  ₹20.70 L    Petrol            Manual          Available in 1 colors                      Glossy Carbon Black (#565657)              N/A
# 190     Tata                 Curvv 1.5 Accomplished Plus A Dark  ₹21.18 L    Diesel            Manual          Available in 1 colors                      Glossy Carbon Black (#565657)              N/A
# 191     Tata                                    Curvv 1.2 Smart  ₹11.24 L    Petrol            Manual          Available in 2 colors   Daytona Grey (#38393b); Pristine White (#fefefe)              N/A
# 192     Tata                                 Curvv 1.2 Creative  ₹14.48 L    Petrol            Manual          Available in 5 colors  Nitro Crimson (#5c121e); Opera Blue (#313a72);...              N/A
# 193     Tata                            Curvv 1.2 Pure Plus DCA  ₹14.83 L    Petrol         Automatic          Available in 4 colors  Opera Blue (#313a72); Flame Red (#6e1618); Day...              N/A
# 194     Tata                               Curvv 1.2 Creative S  ₹15.03 L    Petrol            Manual          Available in 5 colors  Nitro Crimson (#5c121e); Opera Blue (#313a72);...              N/A
# 195     Tata                                Curvv 1.5 Pure Plus  ₹15.12 L    Diesel            Manual          Available in 4 colors  Opera Blue (#313a72); Flame Red (#6e1618); Day...              N/A
# 196     Tata                              Curvv 1.5 Pure Plus S  ₹15.94 L    Diesel            Manual          Available in 4 colors  Opera Blue (#313a72); Flame Red (#6e1618); Day...              N/A
# 197     Tata                           Curvv 1.2 Creative S GDi  ₹16.39 L    Petrol            Manual          Available in 5 colors  Nitro Crimson (#5c121e); Opera Blue (#313a72);...              N/A
# 216     Tata                  Curvv 1.2 Accomplished S Dark DCA  ₹20.70 L    Petrol         Automatic          Available in 1 colors                      Glossy Carbon Black (#565657)              N/A
# 217     Tata                      Curvv 1.5 Accomplished Plus A  ₹20.96 L    Diesel            Manual          Available in 6 colors  Nitro Crimson with Black roof (#5c121e, #0e0e0...              N/A
# 218     Tata                       Curvv 1.5 Accomplished S DCA  ₹21.16 L    Diesel         Automatic          Available in 6 colors  Nitro Crimson with Black roof (#5c121e, #0e0e0...              N/A
# 219     Tata                  Curvv 1.5 Accomplished S Dark DCA  ₹21.38 L    Diesel         Automatic          Available in 1 colors                      Glossy Carbon Black (#565657)              N/A
# 220     Tata              Curvv 1.2 Accomplished Plus A DCA GDi  ₹22.07 L    Petrol         Automatic          Available in 6 colors  Nitro Crimson with Black roof (#5c121e, #0e0e0...              N/A
# 221     Tata             Curvv 1.2 Accomplished Plus A Dark DCA  ₹22.40 L    Petrol         Automatic          Available in 1 colors                      Glossy Carbon Black (#565657)              N/A
# 222     Tata                  Curvv 1.5 Accomplished Plus A DCA  ₹22.70 L    Diesel         Automatic          Available in 6 colors  Nitro Crimson with Black roof (#5c121e, #0e0e0...              N/A
# 223     Tata             Curvv 1.5 Accomplished Plus A Dark DCA  ₹22.92 L    Diesel         Automatic          Available in 1 colors                      Glossy Carbon Black (#565657)              N/A
# 224     Tata                                           Tigor XM   ₹6.54 L    Petrol            Manual          Available in 2 colors   Pristine White (#dcdddf); Daytona Grey (#373739)              N/A
# 225     Tata                                     Tigor XZA Plus   ₹9.53 L    Petrol         Automatic          Available in 5 colors  Meteor Bronze (#a07f52); Arizona Blue (#293b7e...              N/A
# 226     Tata                                           Tigor XT   ₹7.60 L    Petrol            Manual          Available in 2 colors   Daytona Grey (#373739); Pristine White (#dcdddf)              N/A
# 227     Tata                                          Tigor XTA   ₹8.21 L    Petrol         Automatic          Available in 2 colors   Daytona Grey (#373739); Pristine White (#dcdddf)              N/A
# 228     Tata                                           Tigor XZ   ₹8.26 L    Petrol            Manual          Available in 2 colors   Daytona Grey (#373739); Pristine White (#dcdddf)              N/A
# 229     Tata                                       Tigor XT CNG   ₹8.71 L       CNG            Manual          Available in 2 colors   Daytona Grey (#373739); Pristine White (#dcdddf)              N/A
# 230     Tata                                          Tigor XZA   ₹8.87 L    Petrol         Automatic          Available in 3 colors  Arizona Blue (#293b7e); Daytona Grey (#373739)...              N/A
# 231     Tata                                      Tigor XZ Plus   ₹8.92 L    Petrol            Manual          Available in 5 colors  Meteor Bronze (#a07f52); Arizona Blue (#293b7e...              N/A
# 232     Tata                                       Tigor XZ CNG   ₹9.37 L       CNG            Manual          Available in 3 colors  Arizona Blue (#293b7e); Daytona Grey (#373739)...              N/A
# 233     Tata                                  Tigor XZ Plus Lux   ₹9.47 L    Petrol            Manual          Available in 5 colors  Meteor Bronze (#a07f52); Arizona Blue (#293b7e...              N/A
# 234     Tata                                      Tigor XZA CNG   ₹9.97 L       CNG         Automatic          Available in 3 colors  Arizona Blue (#293b7e); Daytona Grey (#373739)...              N/A
# 235     Tata                                  Tigor XZ Plus CNG  ₹10.03 L       CNG            Manual          Available in 5 colors  Meteor Bronze (#a07f52); Arizona Blue (#293b7e...              N/A
# 236     Tata                              Tigor XZ Plus Lux CNG  ₹10.58 L       CNG            Manual          Available in 5 colors  Meteor Bronze (#a07f52); Arizona Blue (#293b7e...              N/A
# ...
# 261     Tata                               Altroz 1.2 Smart CNG   ₹8.97 L       CNG            Manual          Available in 5 colors  Pristine White (#e6e6e6); Pure Grey (#8d8b8c);...              N/A
# 262     Tata                                Altroz 1.2 Pure CNG   ₹9.96 L       CNG            Manual          Available in 5 colors  Pristine White (#e6e6e6); Royal Blue (#0f173c)...              N/A
# 263     Tata                            Altroz 1.2 Creative CNG  ₹11.06 L       CNG            Manual          Available in 5 colors  Dune Glow (#9d9080); Pure Grey (#8d8b8c); Embe...              N/A
# 264     Tata                          Altroz 1.2 Creative S CNG  ₹11.29 L       CNG            Manual          Available in 5 colors  Pristine White (#e6e6e6); Pure Grey (#8d8b8c);...              N/A
# 265     Tata                      Altroz 1.2 Accomplished S CNG  ₹12.93 L       CNG            Manual          Available in 5 colors  Pristine White (#e6e6e6); Pure Grey (#8d8b8c);...              N/A
# 266     Tata                                  Altroz 1.2 Pure S   ₹9.13 L    Petrol            Manual          Available in 5 colors  Pure Grey (#8d8b8c); Ember Glow (#be3c20); Roy...              N/A
# 267     Tata                                Altroz 1.2 Pure AMT   ₹9.39 L    Petrol         Automatic          Available in 5 colors  Pure Grey (#8d8b8c); Ember Glow (#be3c20); Roy...              N/A
# 268     Tata                              Altroz 1.2 Pure S AMT   ₹9.79 L    Petrol         Automatic          Available in 5 colors  Pure Grey (#8d8b8c); Ember Glow (#be3c20); Roy...              N/A
# 269     Tata                                Altroz 1.2 Creative   ₹9.83 L    Petrol            Manual          Available in 5 colors  Pure Grey (#8d8b8c); Ember Glow (#be3c20); Roy...              N/A
# 270     Tata                              Altroz 1.2 Creative S  ₹10.23 L    Petrol            Manual          Available in 5 colors  Pure Grey (#8d8b8c); Ember Glow (#be3c20); Roy...              N/A
# 271     Tata                             Altroz 1.5 Pure Diesel  ₹10.32 L    Diesel            Manual          Available in 5 colors  Pure Grey (#8d8b8c); Ember Glow (#be3c20); Roy...              N/A
# 272     Tata                              Altroz 1.2 Pure S CNG  ₹10.35 L       CNG            Manual          Available in 5 colors  Pure Grey (#8d8b8c); Ember Glow (#be3c20); Roy...              N/A
# 273     Tata                            Altroz 1.2 Creative AMT  ₹10.49 L    Petrol         Automatic          Available in 5 colors  Pure Grey (#8d8b8c); Ember Glow (#be3c20); Roy...              N/A
# 274     Tata                          Altroz 1.2 Creative S AMT  ₹10.89 L    Petrol         Automatic          Available in 5 colors  Pure Grey (#8d8b8c); Ember Glow (#be3c20); Roy...              N/A
# 275     Tata                          Altroz 1.2 Accomplished S  ₹11.26 L    Petrol            Manual          Available in 5 colors  Pure Grey (#8d8b8c); Ember Glow (#be3c20); Roy...              N/A
# 276     Tata                          Altroz 1.2 Creative S DCA  ₹12.02 L    Petrol         Automatic          Available in 5 colors  Pure Grey (#8d8b8c); Ember Glow (#be3c20); Roy...              N/A
# 277     Tata                       Altroz 1.5 Creative S Diesel  ₹12.33 L    Diesel            Manual          Available in 5 colors  Pure Grey (#8d8b8c); Ember Glow (#be3c20); Roy...              N/A
# 278     Tata                      Altroz 1.2 Accomplished S DCA  ₹13.09 L    Petrol         Automatic          Available in 5 colors  Pure Grey (#8d8b8c); Ember Glow (#be3c20); Roy...              N/A
# 279     Tata                 Altroz 1.2 Accomplished Plus S DCA  ₹13.38 L    Petrol         Automatic          Available in 5 colors  Pure Grey (#8d8b8c); Ember Glow (#be3c20); Roy...              N/A
# 280     Tata                   Altroz 1.5 Accomplished S Diesel  ₹13.43 L    Diesel            Manual          Available in 5 colors  Pure Grey (#8d8b8c); Ember Glow (#be3c20); Roy...              N/A
# 281     Tata                       Harrier EV Adventure 65 ACFC  ₹23.16 L  Electric         Automatic          Available in 2 colors      Pristine White (#f4f4f4); Pure Grey (#909091)              N/A
# 282     Tata                     Harrier EV Adventure S 65 ACFC  ₹23.68 L  Electric         Automatic          Available in 2 colors      Pristine White (#f4f4f4); Pure Grey (#909091)              N/A
# 283     Tata                   Harrier EV Fearless Plus 65 ACFC  ₹25.75 L  Electric         Automatic          Available in 2 colors      Pristine White (#f4f4f4); Pure Grey (#909091)              N/A
# 284     Tata                   Harrier EV Fearless Plus 75 ACFC  ₹26.79 L  Electric         Automatic          Available in 2 colors      Pristine White (#f4f4f4); Pure Grey (#909091)              N/A
# 285     Tata                       Harrier EV Empowered 75 ACFC  ₹29.37 L  Electric         Automatic          Available in 4 colors  Empowered Oxide (#c7c9bf); Nainital Nocturne (...              N/A
# 286     Tata                    Harrier EV Empowered ST 75 ACFC  ₹30.15 L  Electric         Automatic          Available in 4 colors  Empowered Oxide (#c7c9bf); Nainital Nocturne (...              N/A
# 287     Tata                   Harrier EV Empowered AWD 75 ACFC  ₹30.93 L  Electric         Automatic          Available in 4 colors  Empowered Oxide (#c7c9bf); Nainital Nocturne (...              N/A
# 288     Tata                Harrier EV Empowered AWD ST 75 ACFC  ₹31.70 L  Electric         Automatic          Available in 4 colors  Empowered Oxide (#c7c9bf); Nainital Nocturne (...              N/A
# 289     Tata                            Harrier EV Adventure 65  ₹22.66 L  Electric         Automatic          Available in 2 colors      Pristine White (#f4f4f4); Pure Grey (#909091)              N/A
# 290     Tata                          Harrier EV Adventure S 65  ₹23.17 L  Electric         Automatic          Available in 2 colors      Pristine White (#f4f4f4); Pure Grey (#909091)              N/A
# 291     Tata                        Harrier EV Fearless Plus 65  ₹25.24 L  Electric         Automatic          Available in 2 colors      Pristine White (#f4f4f4); Pure Grey (#909091)              N/A
# 292     Tata                        Harrier EV Fearless Plus 75  ₹26.28 L  Electric         Automatic          Available in 2 colors      Pristine White (#f4f4f4); Pure Grey (#909091)              N/A
# 293     Tata                            Harrier EV Empowered 75  ₹28.87 L  Electric         Automatic          Available in 4 colors  Empowered Oxide (#c7c9bf); Nainital Nocturne (...              N/A
# 294     Tata                         Harrier EV Empowered ST 75  ₹29.64 L  Electric         Automatic          Available in 4 colors  Empowered Oxide (#c7c9bf); Nainital Nocturne (...              N/A
# 295     Tata                        Harrier EV Empowered AWD 75  ₹30.42 L  Electric         Automatic          Available in 4 colors  Empowered Oxide (#c7c9bf); Nainital Nocturne (...              N/A
# 296     Tata                     Harrier EV Empowered AWD ST 75  ₹31.19 L  Electric         Automatic          Available in 4 colors  Empowered Oxide (#c7c9bf); Nainital Nocturne (...              N/A
# 297     Tata                         Harrier (2020-2023) 2.0 XE       N/A    Diesel            Manual          Available in 1 colors                              Orcus White (#d9dade)              N/A
# 298     Tata                       Harrier (2020-2023) 2.0 XTA+       N/A    Diesel         Automatic          Available in 5 colors  Daytona Grey (#626d78); Calypso Red (#b01214);...              N/A
# 299     Tata                         Harrier (2020-2023) 2.0 XM       N/A    Diesel            Manual          Available in 4 colors  Daytona Grey (#626d78); Orcus White (#d9dade);...              N/A
# 300     Tata                        Harrier (2020-2023) 2.0 XZ+       N/A    Diesel            Manual         Available in 10 colors  Daytona Grey (#626d78); Daytona Grey + Black\t...              N/A
# 301     Tata          Harrier (2020-2023) 2.0 XTA+ Dark Edition       N/A    Diesel         Automatic          Available in 1 colors                              Atlas Black (#151718)              N/A
# 322     Tata            Harrier (2020-2023) 2.0 XZ Dark Edition       N/A    Diesel            Manual          Available in 1 colors                              Atlas Black (#151718)              N/A
# 323     Tata                    Harrier (2020-2023) 2.0 XT Camo       N/A    Diesel            Manual          Available in 1 colors                       Majesto Camo Green (#374339)              N/A
# 324     Tata                       Harrier (2020-2023) 2.0 XMAS       N/A    Diesel         Automatic          Available in 4 colors  Orcus White (#d9dade); Calypso Red (#b01214); ...              N/A
# 325     Tata           Harrier (2020-2023) 2.0 XZA Dark Edition       N/A    Diesel         Automatic          Available in 1 colors                              Atlas Black (#151718)              N/A
# 326     Tata                   Harrier (2020-2023) 2.0 XZA+ Jet       N/A    Diesel         Automatic          Available in 1 colors                                StarLight (#8d7458)              N/A
# 327     Tata                    Harrier (2020-2023) 2.0 XZ+ Jet       N/A    Diesel            Manual          Available in 1 colors                                StarLight (#8d7458)              N/A
# 328     Tata                       Harrier (2020-2023) 2.0 XZA+       N/A    Diesel         Automatic          Available in 9 colors  Daytona Grey (#626d78); Sparkle Cocoa (#6c6962...              N/A
# 329     Tata             Harrier (2020-2023) 2.0 XZA+ Kaziranga       N/A    Diesel         Automatic          Available in 1 colors  Grassland Beige with Piano Black Roof (#625d47...              N/A
# 330     Tata         Nexon EV Max (2022-2023) XZ Plus 7.2 KW FC       N/A  Electric         Automatic          Available in 3 colors  Intensi Teal with Gray Roof (#00486e, #576b78)...              N/A
# 331     Tata                 Nexon EV Max (2022-2023) XM 3.3 KW       N/A  Electric         Automatic          Available in 3 colors  Intensi-Teal (#00486e); Daytona Grey (#576b78)...              N/A
# 332     Tata     Nexon EV Max (2022-2023) XZ Plus Lux 7.2 KW FC       N/A  Electric         Automatic          Available in 3 colors  Intensi Teal with Gray Roof (#00486e, #576b78)...              N/A
# 333     Tata  Nexon EV Max (2022-2023) XZ Plus Lux 7.2 KW FC...       N/A  Electric         Automatic          Available in 1 colors                                    Black (#181d20)              N/A
# 334     Tata        Nexon EV Max (2022-2023) XZ Plus Lux 3.3 KW       N/A  Electric         Automatic          Available in 3 colors  Intensi Teal with Gray Roof (#00486e, #576b78)...              N/A
# 335     Tata            Nexon EV Max (2022-2023) XZ Plus 3.3 KW       N/A  Electric         Automatic          Available in 3 colors  Intensi Teal with Gray Roof (#00486e, #576b78)...              N/A
# 336     Tata              Nexon EV Max (2022-2023) XM 7.2 KW FC       N/A  Electric         Automatic          Available in 3 colors  Intensi Teal (#00486e); Pristine White (#f8f4f...              N/A
# 337     Tata  Nexon EV Max (2022-2023) XZ Plus Lux 3.3 KW Da...       N/A  Electric         Automatic          Available in 1 colors                                    Black (#181d20)              N/A
# 338     Tata    Nexon EV Max (2022-2023) XZ Plus Lux 3.3 KW Jet       N/A  Electric         Automatic          Available in 1 colors      StarLight with Silver Roof (#8d7458, #C0C0C0)              N/A
# 339     Tata  Nexon EV Max (2022-2023) XZ Plus Lux 7.2 KW FC...       N/A  Electric         Automatic          Available in 1 colors      StarLight with Silver Roof (#8d7458, #C0C0C0)              N/A
#
# Data saved to scraped_tata_cars_with_colors.csv
